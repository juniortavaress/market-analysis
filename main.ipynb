# %% [markdown]
# ## OBJETIVO
#     Esse script visa filtrar de forma simplificada as ações presente na bolsa brasileira, para isso se usou um arquivo.csv retirado do site status-invest e posteriormente aplicado filtro pré determinados no código, visando reduzir a quantidade de ações para se analisár.

# %%
#importando banco de dados

import pandas as pd

tabela = pd.read_csv("banco de dados.csv", sep=";")
#tabela = tabela.drop("CustomerID", axis=1)          #drop exclui uma linha ou coluna da tabela, axis = 0 para linha, axis = 1 para coluna.
display(tabela)
# Out:
#     TICKER  PRECO    DY     P/L   P/VP P/ATIVOS MARGEM BRUTA MARGEM EBIT  \
# 0    AALR3  24,13   NaN  -11,54   3,15     1,11        30,83       -1,55
# 1    ABCB4  18,39  8,53    5,36   0,79     0,08        30,57       22,37
# 2    ABEV3  14,93   5,1   15,96   2,77     1,74        49,71       22,46
# 3    ADHM3   1,56   NaN   -4,09  -1,29   105,12          100  -13.548,48
# 4    AERI3   1,23   NaN   -8,11   1,09     0,29        13,11        9,22
# ..     ...    ...   ...     ...    ...      ...          ...         ...
# 615  WIZC3   6,33  7,03    8,95   2,58     0,44        57,99       36,42
# 616  WLMM3   19,6  4,03    5,82   1,11     0,82         13,1        7,72
# 617  WLMM4  20,59  4,22    6,12   1,16     0,86         13,1        7,72
# 618  YDUQ3  20,75   NaN  440,52   2,07     0,67        57,39       15,09
# 619  ZAMP3   4,18   NaN  -14,46   0,81     0,29        64,65        2,54
#
#     MARG. LIQUIDA   P/EBIT  ... PATRIMONIO / ATIVOS PASSIVOS / ATIVOS  \
# 0           -22,5  -167,73  ...                0,35              0,63
# 1           17,25     4,14  ...                 0,1              0,91
# 2           18,03    12,81  ...                0,63              0,36
# 3      -18.860,61    -5,69  ...              -81,72             82,72
# 4            -4,2      3,7  ...                0,26              0,74
# ..            ...      ...  ...                 ...               ...
# 615         11,37     2,79  ...                0,17              0,59
# 616          5,71     4,31  ...                0,74              0,26
# 617          5,71     4,53  ...                0,74              0,26
# 618          0,31     9,06  ...                0,32              0,67
# 619         -2,13    12,16  ...                0,35              0,65
#
#     GIRO ATIVOS CAGR RECEITAS 5 ANOS CAGR LUCROS 5 ANOS  \
# 0          0,43                 0,13                NaN
# 1          0,08                 18,7              12,65
# 2           0,6                10,72              15,19
# 3          0,14                  NaN                NaN
# 4          0,84                  NaN                NaN
# ..          ...                  ...                ...
# 615        0,43                12,37              -6,64
# 616        2,47                32,16                NaN
# 617        2,47                32,16                NaN
# 618        0,49                  6,2             -49,08
# 619        0,92                15,36                NaN
#
#      LIQUIDEZ MEDIA DIARIA    VPA    LPA  PEG Ratio    VALOR DE MERCADO
# 0             8.099.333,33   7,67  -2,09      -0,02    2.854.405.650,08
# 1            16.355.785,26   23,4   3,43       0,22    4.144.231.862,94
# 2           352.772.132,44    5,4   0,94       1,67  235.992.422.594,32
# 3                      NaN  -1,21  -0,38      -0,58       25.439.770,20
# 4             8.215.907,54   1,13  -0,15       0,02      942.442.550,88
# ..                     ...    ...    ...        ...                 ...
# 615           4.020.291,23   2,45   0,71       -0,3    1.007.415.876,60
# 616              10.010,00  17,72   3,37       0,25      733.372.547,50
# 617             107.017,32  17,72   3,37       0,26      733.372.547,50
# 618         101.241.640,64  10,03   0,05      -4,77    6.438.320.766,33
# 619           8.547.777,26   5,19  -0,29       0,33    1.156.492.877,40
#
# [620 rows x 30 columns]

# %%
# Removendo colunas não necessárias
tabela = tabela.drop(["P/ATIVOS", "PSR", "P/CAP. GIRO", "P/EBIT", "P. AT CIR. LIQ.", "MARGEM EBIT", "DIVIDA LIQUIDA / EBIT", "PASSIVOS / ATIVOS", "MARGEM BRUTA", "MARG. LIQUIDA", " VPA", " LPA", "GIRO ATIVOS"], axis=1)  
display(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TICKER                  620 non-null    object
#  1   PRECO                   620 non-null    object
#  2   DY                      339 non-null    object
#  3   P/L                     620 non-null    object
#  4   P/VP                    617 non-null    object
#  5   EV/EBIT                 613 non-null    object
#  6   DIV. LIQ. / PATRI.      485 non-null    object
#  7   LIQ. CORRENTE           587 non-null    object
#  8   ROE                     617 non-null    object
#  9   ROA                     620 non-null    object
#  10  ROIC                    563 non-null    object
#  11  PATRIMONIO / ATIVOS     620 non-null    object
#  12  CAGR RECEITAS 5 ANOS    535 non-null    object
#  13  CAGR LUCROS 5 ANOS      319 non-null    object
#  14   LIQUIDEZ MEDIA DIARIA  482 non-null    object
#  15   PEG Ratio              617 non-null    object
#  16   VALOR DE MERCADO       613 non-null    object
# dtypes: object(17)
# memory usage: 82.5+ KB
# None

# %%
# Filtrando os indicadores básicos analisádos
# Nessa parte o usuário pode editar e filtrar os indicadores conforme seu perfil de investimento

tabela["DY"] = tabela["DY"].str.replace(".", "", regex=True).str.replace(",", ".").astype(float)
tabela["P/L"] = tabela["P/L"].str.replace(".", "", regex=True).str.replace(",", ".").astype(float)
tabela["P/VP"] = tabela["P/VP"].str.replace(".", "", regex=True).str.replace(",", ".").astype(float)
tabela["EV/EBIT"] = tabela["EV/EBIT"].str.replace(".", "", regex=True).str.replace(",", ".").astype(float)
tabela["ROIC"] = tabela["ROIC"].str.replace(".", "", regex=True).str.replace(",", ".").astype(float)
tabela["DIV. LIQ. / PATRI."] = tabela["DIV. LIQ. / PATRI."].str.replace(",", ".").astype(float)
tabela["CAGR RECEITAS 5 ANOS"] = tabela["CAGR RECEITAS 5 ANOS"].str.replace(",", ".").astype(float)

tabela = tabela[(tabela["DY"] >= 4) & (tabela["DY"] <=16)]
tabela = tabela[(tabela["P/L"] >= 3) & (tabela["P/L"] <=20)]  
tabela = tabela[tabela["P/VP"] <=5] 
tabela = tabela[tabela["EV/EBIT"] <=10]  
tabela = tabela[tabela["ROIC"] >= 12]
tabela = tabela[tabela["DIV. LIQ. / PATRI."] <= 4]

# %%
# As empresas na bolsa são negociadas por um ticker de quatro letras e um número (AALR3).
# O número indica se a ações é ordinária ou preferencial, ticker como AALR3 e AALR4 pertencem a mesma empresa.
# Desse modo foi deixado apenas um ticker por empresa.

tabela["Ticker"] = tabela["TICKER"].str.extract(r'([A-Z]{4})')
duplicatas = tabela.duplicated(subset=["Ticker"], keep=False)
tabela = tabela[~duplicatas]

tabela = tabela.drop("Ticker", axis=1)
print("Número de linhas:", len(tabela))
display(tabela)
# Out:
# Número de linhas: 24
#     TICKER  PRECO     DY    P/L  P/VP  EV/EBIT  DIV. LIQ. / PATRI.  \
# 169  CPFE3  36,05   5.83   7.43  2.33     5.53                1.10
# 191  CSUD3  14,45   6.73   7.71  1.52     5.70                0.03
# 202  CXSE3  10,39   8.32   9.62  2.64     8.17               -0.11
# 225  EGIE3  44,85   7.41  12.59  3.95     8.52                1.58
# 243  ENGI4   8,95   4.38   8.99  1.61     7.45                1.93
# 258  ETER3  10,91   6.30   5.74  0.97     4.73                0.05
# 342  KEPL3   9,29  10.83   4.94  2.58     3.41               -0.22
# 352  LEVE3  44,84   9.72   9.16  3.34     7.21                0.01
# 410  MTSA4  47,48   5.44   4.42  1.04     3.51               -0.19
# 420  NEOE3   20,6   5.62   5.30  0.89     6.36                1.31
# 463  POSI3   8,35   6.14   4.20  0.85     3.60                0.66
# 470  PTBL3   8,38   6.18  11.77  2.58     8.11                1.60
# 482  RANI3   9,84   7.61   6.95  2.05     5.74                0.68
# 490  RECV3  23,25   4.56   7.16  1.66     5.68               -0.07
# 491  REDE3    5,7  12.44   9.03  3.24     6.50                2.59
# 497  ROMI3  14,47   6.93   5.82  1.17     6.43                0.46
# 505  RSUL4  63,22   4.61   5.64  2.44     1.12               -0.24
# 523  SLCE3  43,14   6.85   9.18  1.87     5.77                0.52
# 566  TGMA3  21,99   6.29   8.29  1.81     6.22               -0.10
# 572  TKNO4     60   6.83   5.04  0.66     3.15               -0.16
# 580  TRPL4  25,37   4.19   6.77  0.99     6.93                0.41
# 589  UNIP5     88  15.00   8.07  3.57     3.96                0.01
# 594  VALE3  71,77   7.93   3.95  1.72     5.29                0.22
# 615  WIZC3   6,33   7.03   8.95  2.58     3.09                0.29
#
#     LIQ. CORRENTE    ROE    ROA   ROIC PATRIMONIO / ATIVOS  \
# 169          1,13  31,32   7,72  19.94                0,25
# 191          1,22  19,76  12,75  16.32                0,65
# 202          2,68  27,48  25,67  26.24                0,93
# 225          1,19  31,37   7,32  19.81                0,23
# 243          1,18  17,88   3,28  12.02                0,18
# 258          2,92  16,94  10,04  16.29                0,59
# 342          1,72  52,26  26,05  40.09                 0,5
# 352          2,05  36,43  19,38  28.15                0,53
# 410          3,06  23,65  16,98  19.70                0,72
# 420          1,16  16,86      5  12.64                 0,3
# 463          1,94  20,34   7,17  19.96                0,35
# 470          1,13  21,89   3,65  12.97                0,17
# 482          2,93  29,47   9,75  13.69                0,33
# 490          0,87  23,23  13,78  22.53                0,59
# 491          1,28  35,89   5,18  17.29                0,14
# 497           2,1  20,09  10,04  12.06                 0,5
# 505          2,28  43,25  20,04  45.41                0,46
# 523          1,78  20,34   6,64  19.01                0,33
# 566          2,68  21,86  15,48  17.29                0,71
# 572          2,68  13,06   9,67  14.73                0,74
# 580          3,15  14,59   7,31  12.84                 0,5
# 589          2,14  44,27  18,75  34.14                0,42
# 594          1,12  43,44  18,53  23.96                0,43
# 615          1,09  28,86   4,92  21.99                0,17
#
#      CAGR RECEITAS 5 ANOS CAGR LUCROS 5 ANOS  LIQUIDEZ MEDIA DIARIA  \
# 169                  8.03               36,5          73.582.956,49
# 191                  1.99              11,62             740.384,23
# 202                   NaN              20,03          20.150.376,54
# 225                 11.18               7,68          60.315.220,95
# 243                 14.21              29,43             163.415,56
# 258                 12.27                NaN           2.764.227,38
# 342                 25.71                NaN          15.692.321,31
# 352                 13.28               21,5          13.261.768,31
# 410                 27.16              48,38             124.449,33
# 420                 15.85              63,34          50.075.392,56
# 463                 21.15                NaN          16.635.739,62
# 470                 16.49               9,37           9.813.855,72
# 482                 14.44                NaN           9.227.636,85
# 490                   NaN                NaN          48.055.862,92
# 491                 10.99              64,32              34.794,69
# 497                 18.80              42,41           8.563.273,97
# 505                 26.29              13,12             288.635,74
# 523                 34.00              24,39          70.148.470,85
# 566                  4.80              11,03           3.226.794,74
# 572                 19.94                NaN              21.649,30
# 580                 15.07              12,57          40.731.897,46
# 589                 19.21               30,2              29.315,13
# 594                 15.85              36,13       1.878.830.299,74
# 615                 12.37              -6,64           4.020.291,23
#
#      PEG Ratio    VALOR DE MERCADO
# 169       0,53   41.584.862.739,60
# 191       0,32      604.010.000,00
# 202       0,16   31.020.000.000,00
# 225       0,17   36.431.173.591,00
# 243      -0,57   20.998.513.188,92
# 258      -0,11      667.804.775,75
# 342        0,1    1.673.194.410,30
# 352        0,8    5.746.937.715,00
# 410       0,08      526.440.907,40
# 420       0,37   25.040.637.226,24
# 463       0,07    1.182.612.000,00
# 470      -0,22    1.178.650.366,96
# 482       2,87    2.414.321.326,20
# 490       0,12    6.802.288.024,00
# 491      -0,62   11.986.636.764,32
# 497       1,74    1.286.643.652,50
# 505       0,23      156.151.180,50
# 523      -0,33    9.769.255.379,80
# 566       0,13    1.450.744.071,70
# 572       -0,1      192.152.382,63
# 580      -0,39   18.810.043.026,84
# 589      -0,17    8.078.931.178,65
# 594      -0,14  325.492.233.561,80
# 615       -0,3    1.007.415.876,60

# %%
# Salvando em um arquivo.csv para melhor análise do usuário
tabela.to_csv("Indicadores atualizados.csv", index=False, sep=";")
